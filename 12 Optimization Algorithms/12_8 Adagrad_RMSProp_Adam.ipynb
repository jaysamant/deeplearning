# %% [markdown]
# **Adagrad**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **RMSProp**
#
# Instead of accumulating all past squared gradients, RMSProp uses an exponential moving average:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Adam**
#
# Adam combines momentum and RMS Prop
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
